# %%
import pandas as pd
import numpy as np
import csv

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/dev/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin 
import requests
import re
from selenium import webdriver
import time
from selenium.webdriver.support.ui import WebDriverWait as wait

# Download IMDB's Top 250 data
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []
dataset = []
# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 1):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
#            "year": year,
#             "place": place,
#             "star_cast": crew[index],
            "rating": ratings[index],
#             "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    #print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'],  item['link'])
    url =  'http://www.imdb.com'+ item['link'][:17]+'reviews'
    driver = webdriver.Chrome('/home/dev/Downloads/chromedriver_linux64/chromedriver')
    driver.get(url)

    labtn = driver.find_element_by_id('load-more-trigger')
    labtn.click()

    wait(driver, 15).until(lambda x: len(driver.find_elements_by_css_selector("div.lister-item-content")) > 39)
    source_code = driver.page_source
    soup = BeautifulSoup(source_code, 'lxml')
    containers=soup.find_all('div', class_ = 'lister-item-content')
   
    for container in containers:
        if container.find('a', class_ = 'title' ) is not None:
            title = container.a.text.strip()
            bar = container.find('div', class_ = 'ipl-ratings-bar')
            if bar is None:
                continue
            else:
                rating = bar.text.strip()  
                content_cont = container.find('div', class_ = 'text show-more__control')
                if content_cont is not None:
                    content = content_cont.text.strip()
                else:
                    content_cont = container.find('div', class_ = 'text show-more__control clickable')
                    content = content_cont.text.strip()
                content = title+' '+content
                movies = {
                    "title" : item['movie_title'],
                    "rating" : item['rating'],
                    "reviews": content,
                    "user_ratings":rating
                }
                dataset.append(movies)
    
   
    #print(movies)           
    driver.quit()
    
#print(dataset)
# df=pd.DataFrame(dataset)
# print(df)
print(len(dataset))
# Out:
# 48

# %%
url = 'https://www.imdb.com/chart/bottom'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []
# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 1):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
#            "year": year,
#             "place": place,
#             "star_cast": crew[index],
            "rating": ratings[index],
#             "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    #print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'],  item['link'])
    url =  'http://www.imdb.com'+ item['link'][:17]+'reviews'
    driver = webdriver.Chrome('/home/dev/Downloads/chromedriver_linux64/chromedriver')
    driver.get(url)

    labtn = driver.find_element_by_id('load-more-trigger')
    labtn.click()

    wait(driver, 15).until(lambda x: len(driver.find_elements_by_css_selector("div.lister-item-content")) > 39)
    source_code = driver.page_source
    soup = BeautifulSoup(source_code, 'lxml')
    containers=soup.find_all('div', class_ = 'lister-item-content')
   
    for container in containers:
        if container.find('a', class_ = 'title' ) is not None:
            title = container.a.text.strip()
            bar = container.find('div', class_ = 'ipl-ratings-bar')
            if bar is None:
                continue
            else:
                rating = bar.text.strip()  
                content_cont = container.find('div', class_ = 'text show-more__control')
                if content_cont is not None:
                    content = content_cont.text.strip()
                else:
                    content_cont = container.find('div', class_ = 'text show-more__control clickable')
                    content = content_cont.text.strip()
                content = title+' '+content
                movies = {
                    "title" : item['movie_title'],
                    "rating" : item['rating'],
                    "reviews": content,
                    "user_ratings":rating
                }
                dataset.append(movies)
    
   
   
    #print(movies)           
    driver.quit()
print(len(dataset))

# print(df)
# Out:
# 96

# %%
# Download IMDB's Top 250 data
url = 'https://www.imdb.com/list/ls058813655/?sort=list_order,asc&st_dt=&mode=simple&page=1&ref_=ttls_vw_smp'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

# movies = soup.select('td.titleColumn')
# links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
# crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
# ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
# votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

movies = soup.find_all('div',class_='lister-col-wrapper')

imdb = []
# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 1):
    # Seperate movie into: 'place', 'title', 'year'
#     movie_string = movies[index].get_text()
#     movie = (' '.join(movie_string.split()).replace('.', ''))
#     movie_title = movie[len(str(index))+1:-7]
    movie_title = movies[index].a.text
    rating_temp = movies[index].find('div',class_='col-imdb-rating')
    rating = rating_temp.strong.text.strip()
    link=movies[index].a.attrs.get('href')
#     year = re.search('(.*?)(.∗?)', movie_string).group(1)
#     place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
#             "year": year,
#             "place": place,
#             "star_cast": crew[index],
            "rating": rating,
#             "vote": votes[index],
            "link": link}
    imdb.append(data)

for item in imdb:
    #print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'],  item['link'])
    url =  'http://www.imdb.com'+ item['link'][:17]+'reviews'
    driver = webdriver.Chrome('/home/dev/Downloads/chromedriver_linux64/chromedriver')
   # driver = webdriver.Chrome('/home/udbhav/Downloads/chromedriver')
    driver.get(url)

    labtn = driver.find_element_by_id('load-more-trigger')
    labtn.click()

    wait(driver, 15).until(lambda x: len(driver.find_elements_by_css_selector("div.lister-item-content")) > 39)
    source_code = driver.page_source
    soup = BeautifulSoup(source_code, 'lxml')
    containers=soup.find_all('div', class_ = 'lister-item-content')
   
    for container in containers:
        if container.find('a', class_ = 'title' ) is not None:
            title = container.a.text.strip()
            bar = container.find('div', class_ = 'ipl-ratings-bar')
            if bar is None:
                continue
            else:
                rating = bar.text.strip()  
                content_cont = container.find('div', class_ = 'text show-more__control')
                if content_cont is not None:
                    content = content_cont.text.strip()
                else:
                    content_cont = container.find('div', class_ = 'text show-more__control clickable')
                    content = content_cont.text.strip()
                content = title+' '+content
                movies = {
                    "title" : item['movie_title'],
                    "rating" : item['rating'],
                    "reviews": content,
                    "user_ratings":rating
                }
                dataset.append(movies)
    
   
    #print(movies)           
    driver.quit()
    
#print(dataset)
f = open("sample.csv", "w")
writer = csv.DictWriter(
    f, fieldnames=["title", "rating", "reviews","user_ratings"])
writer.writeheader()
writer.writerows(dataset)
f.close()
df = pd.read_csv('sample.csv')
print(df)
print(len(dataset))
# Out:
#                         title    rating  \
# 0    The Shawshank Redemption  9.217025
# 1    The Shawshank Redemption  9.217025
# 2    The Shawshank Redemption  9.217025
# 3    The Shawshank Redemption  9.217025
# 4    The Shawshank Redemption  9.217025
# 5    The Shawshank Redemption  9.217025
# 6    The Shawshank Redemption  9.217025
# 7    The Shawshank Redemption  9.217025
# 8    The Shawshank Redemption  9.217025
# 9    The Shawshank Redemption  9.217025
# 10   The Shawshank Redemption  9.217025
# 11   The Shawshank Redemption  9.217025
# 12   The Shawshank Redemption  9.217025
# 13   The Shawshank Redemption  9.217025
# 14   The Shawshank Redemption  9.217025
# 15   The Shawshank Redemption  9.217025
# 22   A movie revolution upon all others We have all...        10/10
# 23   Awesome movie - The Shawshank Redemption (1994...        10/10
# 24   My own personal view I don't care if there are...        10/10
# 25   What a touching movie ! It is really amazing m...        10/10
# 26   Great story, wondrously told and acted At the ...         8/10
# 27   The closest thing to poetic perfection Hollywo...        10/10
# 28   Richly human, uplifting Deservedly ranked at t...        10/10
# 29   the Shawshank redemption is a world class film...        10/10
# ..                                                 ...          ...
# 114  Best to date This is by far the best Marvel fi...        10/10
# 115  A celebration of ten wonderful years of entert...         9/10
# 116  Noise and Confusion Not a fan of superheroes b...         1/10
# 117  Do not believe the ratings, this movie is not ...         8/10
# 118  I expected more Not everything that glitters i...         1/10
# 119  Long and Boring: Worst movie of 2018 so far I'...         1/10
# 120  Harry Potter and the deathly hollows This is t...         1/10
# 121  "Avengers: Infinity War" is dishonest, idiotic...         1/10
# 122  Film for kids This is a film made for children...         1/10
# 123  Lots of dying characters, plot holes and CGI d...         1/10
# 124  Wow that was trash Deserves like not even a 1 ...         1/10
# 125  What a load of Crud!!!!!! I never write review...         1/10
# 126  Worst Marvel film ever so far I just can't com...        10/10
# 127  I sort of liked it ? Ok I know rating a movie ...         2/10
# 128  Heavy Indigestion Sometimes when you cook a di...         2/10
# 129  Please stop the Hype! Suffering hype fatigue, ...         2/10
# 130  Think Twice !!! For those who hasn't watch it ...         2/10
# 131  Grade - Incomplete This is an incomplete film....         2/10
# 132  Too many characters, prolonged action scenes b...         2/10
# 133  Not impressed Nice visuals :-), but honestly, ...         3/10
# 134  Before you spend your hard-earned cash... We o...         3/10
# 135  Very poorly handled If you love all the other ...         2/10
# 136  Won't watch avengers part 4 The comedy was goo...         2/10
# 137  Once again, no story, just bangs and booms. Un...         1/10
# 138  cannot figure out why this is a box office suc...         2/10
# 139  Bang boom bang for the simple minded... Will a...         1/10
# 140  It certainly is large Lotsa flashing lights an...         1/10
# 141  Silly movie It totally wasn't how i expected i...         1/10
# 142  All action no story The director has just spaf...         4/10
# 143  According to fanboys: as good as The Godfather...         1/10
#
# [144 rows x 4 columns]
# 144

# %%
import re
assert df['rating'].isnull().count()==len(df['rating'])
assert df['reviews'].isnull().count()==len(df['reviews'])

# %%
df.iloc[0]['reviews']
from ast import literal_eval

# %%
df.head(280)
# Out:
#                         title    rating  \
# 0    The Shawshank Redemption  9.217025
# 1    The Shawshank Redemption  9.217025
# 2    The Shawshank Redemption  9.217025
# 3    The Shawshank Redemption  9.217025
# 4    The Shawshank Redemption  9.217025
# 5    The Shawshank Redemption  9.217025
# 6    The Shawshank Redemption  9.217025
# 7    The Shawshank Redemption  9.217025
# 8    The Shawshank Redemption  9.217025
# 9    The Shawshank Redemption  9.217025
# 10   The Shawshank Redemption  9.217025
# 11   The Shawshank Redemption  9.217025
# 12   The Shawshank Redemption  9.217025
# 13   The Shawshank Redemption  9.217025
# 14   The Shawshank Redemption  9.217025
# 15   The Shawshank Redemption  9.217025
# 16   The Shawshank Redemption  9.217025
# 23   Awesome movie - The Shawshank Redemption (1994...        10/10
# 24   My own personal view I don't care if there are...        10/10
# 25   What a touching movie ! It is really amazing m...        10/10
# 26   Great story, wondrously told and acted At the ...         8/10
# 27   The closest thing to poetic perfection Hollywo...        10/10
# 28   Richly human, uplifting Deservedly ranked at t...        10/10
# 29   the Shawshank redemption is a world class film...        10/10
# ..                                                 ...          ...
# 114  Best to date This is by far the best Marvel fi...        10/10
# 115  A celebration of ten wonderful years of entert...         9/10
# 116  Noise and Confusion Not a fan of superheroes b...         1/10
# 117  Do not believe the ratings, this movie is not ...         8/10
# 118  I expected more Not everything that glitters i...         1/10
# 119  Long and Boring: Worst movie of 2018 so far I'...         1/10
# 120  Harry Potter and the deathly hollows This is t...         1/10
# 121  "Avengers: Infinity War" is dishonest, idiotic...         1/10
# 122  Film for kids This is a film made for children...         1/10
# 123  Lots of dying characters, plot holes and CGI d...         1/10
# 124  Wow that was trash Deserves like not even a 1 ...         1/10
# 125  What a load of Crud!!!!!! I never write review...         1/10
# 126  Worst Marvel film ever so far I just can't com...        10/10
# 127  I sort of liked it ? Ok I know rating a movie ...         2/10
# 128  Heavy Indigestion Sometimes when you cook a di...         2/10
# 129  Please stop the Hype! Suffering hype fatigue, ...         2/10
# 130  Think Twice !!! For those who hasn't watch it ...         2/10
# 131  Grade - Incomplete This is an incomplete film....         2/10
# 132  Too many characters, prolonged action scenes b...         2/10
# 133  Not impressed Nice visuals :-), but honestly, ...         3/10
# 134  Before you spend your hard-earned cash... We o...         3/10
# 135  Very poorly handled If you love all the other ...         2/10
# 136  Won't watch avengers part 4 The comedy was goo...         2/10
# 137  Once again, no story, just bangs and booms. Un...         1/10
# 138  cannot figure out why this is a box office suc...         2/10
# 139  Bang boom bang for the simple minded... Will a...         1/10
# 140  It certainly is large Lotsa flashing lights an...         1/10
# 141  Silly movie It totally wasn't how i expected i...         1/10
# 142  All action no story The director has just spaf...         4/10
# 143  According to fanboys: as good as The Godfather...         1/10
#
# [144 rows x 4 columns]

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('wordnet')
from nltk.stem import wordnet
# Out:
# [nltk_data] Downloading package wordnet to /home/dev/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/dev/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/dev/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.corpus import stopwords
import string
# # Apply this code to every textual string

wnl = WordNetLemmatizer() 
reviews=df['reviews']
count=0
for review in df['reviews']:
    review = re.sub('''[!@#$+%*:();/.,?"'-]''', ' ', review)
    word_list = review.split() 
    
    filtered_words = [word for word in word_list if word not in stopwords.words('english')]
    review = ' '.join(filtered_words)
    temp=''
    for word, tag in pos_tag(word_tokenize(review)):
        print (word + ':')
        if tag.startswith("NN"):
            temp =' '.join(wnl.lemmatize(word, pos='n'))
        elif tag.startswith('VB'):
            temp =' '.join(wnl.lemmatize(word, pos='v'))
        elif tag.startswith('JJ'):
            temp =' '.join(wnl.lemmatize(word, pos='a'))
        else:
            temp =' '.join(word)
        print(word)
# print(' '.join(lemmatize_all("i want better dogs")))
# prints 'i want good dog'
    
    df.iloc[count ,2]=review
    count = count+1
df = df.applymap(lambda s:s.lower() if type(s) == str else s)
print(df['reviews'])
# Out:
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# i:
# i
# want:
# want
# better:
# good
# dogs:
# dog
# 0      tied best movie ever seen want write 234th com...
# 1      classic piece unforgettable film making oscar ...
# 2      movies made movie ordinary hollywood flick gre...
# 3      shawshank redeems hollywood hollywood usually ...
# 4      rent shawshank trying save money last film tit...
# 5      birds meant caged shawshank redemption written...
# 6      stephen king best adapted movie misery stand b...
# 7      shawshank redemption one finest films made rec...
# 8      simply known movie whenever talk movie friends...
# 9      eternal hope lost count number times seen movi...
# 10     simply amazing best film 90 shawshank redempti...
# 11     excellent piece art watch movie minimum 5 6 ti...
# 12     absolute greatest movie time life forever chan...
# 13     make questions formula gives kick darn good mo...
# 14     oh godmother three words oh god supposed descr...
# 15     best story ever told film believe film best st...
# 16     wonderful movie first see young understand thi...
# 17     prison thriller violence hatred corruption fri...
# 18     greatest movie time movie one time favorites u...
# 19     favorite movies one best movies world many peo...
# 20     busy dying busy living yes spoilers film emoti...
# 21     hope set free remarkable film one favorite mov...
# 22     movie revolution upon others see movies comedi...
# 23     awesome movie shawshank redemption 1994 rare f...
# 24     personal view care poor souls would like belit...
# 25     touching movie really amazing movie ever seen ...
# 26     great story wondrously told acted heart extrao...
# 27     closest thing poetic perfection hollywood ever...
# 28     richly human uplifting deservedly ranked top i...
# 29     shawshank redemption world class film shawshan...
#                              ...
# 114    best date far best marvel film since winter so...
# 115    celebration ten wonderful years entertainment ...
# 116    noise confusion fan superheroes attended movie...
# 117    believe ratings movie nearly good people claim...
# 118    expected everything glitters gold say often sc...
# 119    long boring worst movie 2018 far fan marvel dc...
# 120    harry potter deathly hollows worse film date m...
# 121    avengers infinity war dishonest idiotic simply...
# 122    film kids film made children adults ninja turt...
# 123    lots dying characters plot holes cgi make good...
# 124    wow trash deserves like even 1 star movie noth...
# 125    load crud never write reviews big supporter ma...
# 126    worst marvel film ever far comprehend main cha...
# 127    sort liked ok know rating movie like 2 star go...
# 128    heavy indigestion sometimes cook dish guests t...
# 129    please stop hype suffering hype fatigue year i...
# 130    think twice watch yet need warning see anythin...
# 131    grade incomplete incomplete film thanos collec...
# 132    many characters prolonged action scenes become...
# 133    impressed nice visuals honestly go cinema go e...
# 134    spend hard earned cash occasionally use imdb j...
# 135    poorly handled love mcu films probably love on...
# 136    watch avengers part 4 comedy good ending good ...
# 137    story bangs booms unfortunately computer gener...
# 138    cannot figure box office success 8 minutes ori...
# 139    bang boom bang simple minded 14 year old marve...
# 140    certainly large lotsa flashing lights loud noi...
# 141    silly movie totally expected silly film action...
# 142    action story director spaffed action scenes on...
# 143    according fanboys good godfather movie litterl...
# Name: reviews, Length: 144, dtype: object

# %%
# reviews = ''.join([i for i in reviews if not i.isdigit()])
# reviews = re.sub('''[!@#$+%*:()/.,?"'-]''', ' ', reviews)
# from nltk.corpus import stopwords

# # Apply this code to every textual string
# word_list = reviews.split() 
# filtered_words = [word for word in word_list if word not in stopwords.words('english')]
# reviews = ' '.join(filtered_words)
